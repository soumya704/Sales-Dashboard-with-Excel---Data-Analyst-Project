# %% [markdown]
# # 📊 Sales Dashboard - Jupyter Version by Charlie for Sona 💛

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style='whitegrid')

# %% [markdown]
# ## 📥 Load and Clean the Sales Data

# %%
# Load CSV file
df = pd.read_csv('salesdata-old.csv')

# Keep only relevant columns
df = df[['Row Labels', 'Sum of Sales']]
df.columns = ['Category', 'Sales']

# Preview
df.head()
# Out:
#   Category      Sales
# 0   Phones  330007.10
# 1   Chairs  328167.76
# 2  Storage  223843.59
# 3   Tables  206965.68
# 4  Binders  203412.77

# %% [markdown]
# ## 📊 Sales by Category (Bar Chart)

# %%
plt.figure(figsize=(10,6))
df_sorted = df.sort_values(by='Sales', ascending=True)
sns.barplot(x='Sales', y='Category', data=df_sorted, hue='Category', palette='Blues_r', legend=False)
plt.title('Sales by Category', fontsize=16)
plt.xlabel('Sales')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🥧 Top 5 Categories by Sales (Pie Chart)

# %%
top5 = df.sort_values(by='Sales', ascending=False).head(5)
plt.figure(figsize=(7,7))
plt.pie(top5['Sales'], labels=top5['Category'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Top 5 Categories by Sales')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample monthly sales data
sample_data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    'Sales': [1200, 1500, 1800, 1700, 1600, 2000, 
              2200, 2100, 1900, 2300, 2500, 2400]
}

# Create DataFrame
monthly_df = pd.DataFrame(sample_data)

# Plot area chart
plt.figure(figsize=(12, 6))
plt.fill_between(monthly_df['Month'], monthly_df['Sales'], color='skyblue', alpha=0.5)
plt.plot(monthly_df['Month'], monthly_df['Sales'], marker='o', color='blue')
plt.title('📈 Monthly Sales Trend (Sample Data)', fontsize=16)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\soumy\AppData\Local\Temp\ipykernel_2248\2506508927.py:23: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\soumy\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
